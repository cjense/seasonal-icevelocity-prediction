# %% [markdown]
# # Hyperparameter tuning and cross-validation
#
# Test the data on various models using ensemble learning. Determine the best model for use.
#
# ---

# %% [markdown]
# ### 1. Load packages and open dataset
#
# This example will demonstrate on the middle point which we will use to determine which model is best for predicting all three points.

# %%
import pandas as pd
import numpy as np
import xarray as xr
import plotly.express as px
from pycaret.regression import *

# %%
df = pd.read_csv('../data/clean/Middle_velocity_series_clean.csv')

# %%
df.head()
# Out:
#                   time  VelocitySeries
# 0  2015-01-30 12:00:00       779.53534
# 1  2015-02-11 12:00:00       738.42413
# 2  2015-07-29 12:00:00       741.93330
# 3  2015-09-03 12:00:00       736.29333
# 4  2015-09-15 12:00:00       731.44696

# %% [markdown]
# Create a monthly rolling average of the data to plot with the velocity data.

# %%
# create 12 month moving average
df.rename(columns={'VelocitySeries': 'velocity'}, inplace=True)
df['MA12'] = df['velocity'].rolling(12).mean()

# plot the data and monthly average
fig = px.line(df, x="time", y=["velocity", "MA12"], template = 'plotly_dark')
fig.show()

# %% [markdown]
# Create a series to add to the dataframe for interpretation of time series data. Drop the values that are unnecessary, leaving series, time, and velocity values.

# %%
# create a sequence of numbers
df['series'] = np.arange(1,len(df)+1)
df['time'] = pd.to_datetime(df['time'])

# drop unnecessary columns and re-arrange
df = df[['series', 'time', 'velocity']] 

# check the head of the dataset
df.head()
# Out:
#    series                time   velocity
# 0       1 2015-01-30 12:00:00  779.53534
# 1       2 2015-02-11 12:00:00  738.42413
# 2       3 2015-07-29 12:00:00  741.93330
# 3       4 2015-09-03 12:00:00  736.29333
# 4       5 2015-09-15 12:00:00  731.44696

# %% [markdown]
# Split the data into train and test data. We will use ~75% for training and ~25% for testing.

# %%
# split data into train-test set
train = df[df['time'] < pd.to_datetime('06-01-2021')]
test = df[df['time'] >= pd.to_datetime('06-01-2021')]

# check shape
print("Shape of training data:", train.shape, "Shape of test data:", test.shape)

# calculate percentage
train_percentage = (len(train) / len(df)) * 100
test_percentage = (len(test) / len(df)) * 100

print(f"Training data percentage: {train_percentage:.2f}%")
print(f"Testing data percentage: {test_percentage:.2f}%")
# Out:
# Shape of training data: (272, 3) Shape of test data: (92, 3)
# Training data percentage: 74.73%
# Testing data percentage: 25.27%

# %% [markdown]
# ### 3. Initialize the model
#
# Here we will use Pycaret's setup function to initialize the model, passing the training data, testing data, and the features to predict. The function outputs information about the pipeline that will be used for model selection and tuning.

# %%
# initialize setup
s = setup(data = train, test_data = test, 
          target = 'velocity', fold_strategy = 'timeseries', 
          numeric_features = ['time', 'series'], fold = 6, 
          transform_target = True, session_id = 123,
          data_split_shuffle = False, fold_shuffle = False)
# Out:
# <style type="text/css">
# #T_9b97b_row9_col1, #T_9b97b_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9b97b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b97b_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9b97b_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b97b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b97b_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9b97b_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9b97b_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9b97b_row1_col1" class="data row1 col1" >velocity</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9b97b_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9b97b_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9b97b_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_9b97b_row3_col1" class="data row3 col1" >(364, 3)</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9b97b_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_9b97b_row4_col1" class="data row4 col1" >(364, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9b97b_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_9b97b_row5_col1" class="data row5 col1" >(272, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9b97b_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_9b97b_row6_col1" class="data row6 col1" >(92, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9b97b_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_9b97b_row7_col1" class="data row7 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9b97b_row8_col0" class="data row8 col0" >Date features</td>
#       <td id="T_9b97b_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9b97b_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_9b97b_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9b97b_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_9b97b_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9b97b_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_9b97b_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9b97b_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_9b97b_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9b97b_row13_col0" class="data row13 col0" >Transform target</td>
#       <td id="T_9b97b_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9b97b_row14_col0" class="data row14 col0" >Transform target method</td>
#       <td id="T_9b97b_row14_col1" class="data row14 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9b97b_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_9b97b_row15_col1" class="data row15 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9b97b_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_9b97b_row16_col1" class="data row16 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9b97b_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_9b97b_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9b97b_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_9b97b_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9b97b_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_9b97b_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_9b97b_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_9b97b_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9b97b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_9b97b_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_9b97b_row21_col1" class="data row21 col1" >c9b7</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 4. Compare models
#
# Now, we can compare the models using cross-validation. We sort them based on the mean absolute error (MAE) value which is a measure of error that is not as sensitive to outliers are mean squared error and root mean squared error. We'll also test the first 4 models on the test data, so select those with `n_select`.

# %%
# Test the models
comparison = compare_models(n_select=4, sort='MAE', cross_validation=True)
# Out:
# <style type="text/css">
# #T_1f8b8 th {
#   text-align: left;
# }
# #T_1f8b8_row0_col0, #T_1f8b8_row0_col4, #T_1f8b8_row1_col0, #T_1f8b8_row1_col1, #T_1f8b8_row1_col2, #T_1f8b8_row1_col3, #T_1f8b8_row1_col4, #T_1f8b8_row1_col5, #T_1f8b8_row1_col6, #T_1f8b8_row2_col0, #T_1f8b8_row2_col1, #T_1f8b8_row2_col2, #T_1f8b8_row2_col3, #T_1f8b8_row2_col4, #T_1f8b8_row2_col5, #T_1f8b8_row2_col6, #T_1f8b8_row3_col0, #T_1f8b8_row3_col1, #T_1f8b8_row3_col2, #T_1f8b8_row3_col3, #T_1f8b8_row3_col5, #T_1f8b8_row3_col6, #T_1f8b8_row4_col0, #T_1f8b8_row4_col1, #T_1f8b8_row4_col2, #T_1f8b8_row4_col3, #T_1f8b8_row4_col4, #T_1f8b8_row4_col5, #T_1f8b8_row4_col6, #T_1f8b8_row5_col0, #T_1f8b8_row5_col1, #T_1f8b8_row5_col2, #T_1f8b8_row5_col3, #T_1f8b8_row5_col4, #T_1f8b8_row5_col5, #T_1f8b8_row5_col6, #T_1f8b8_row6_col0, #T_1f8b8_row6_col1, #T_1f8b8_row6_col2, #T_1f8b8_row6_col3, #T_1f8b8_row6_col4, #T_1f8b8_row6_col5, #T_1f8b8_row6_col6, #T_1f8b8_row7_col0, #T_1f8b8_row7_col1, #T_1f8b8_row7_col2, #T_1f8b8_row7_col3, #T_1f8b8_row7_col4, #T_1f8b8_row7_col5, #T_1f8b8_row7_col6, #T_1f8b8_row8_col0, #T_1f8b8_row8_col1, #T_1f8b8_row8_col2, #T_1f8b8_row8_col3, #T_1f8b8_row8_col4, #T_1f8b8_row8_col5, #T_1f8b8_row8_col6, #T_1f8b8_row9_col0, #T_1f8b8_row9_col1, #T_1f8b8_row9_col2, #T_1f8b8_row9_col3, #T_1f8b8_row9_col4, #T_1f8b8_row9_col5, #T_1f8b8_row9_col6, #T_1f8b8_row10_col0, #T_1f8b8_row10_col1, #T_1f8b8_row10_col2, #T_1f8b8_row10_col3, #T_1f8b8_row10_col4, #T_1f8b8_row10_col5, #T_1f8b8_row10_col6, #T_1f8b8_row11_col0, #T_1f8b8_row11_col1, #T_1f8b8_row11_col2, #T_1f8b8_row11_col3, #T_1f8b8_row11_col4, #T_1f8b8_row11_col5, #T_1f8b8_row11_col6, #T_1f8b8_row12_col0, #T_1f8b8_row12_col1, #T_1f8b8_row12_col2, #T_1f8b8_row12_col3, #T_1f8b8_row12_col4, #T_1f8b8_row12_col5, #T_1f8b8_row12_col6, #T_1f8b8_row13_col0, #T_1f8b8_row13_col1, #T_1f8b8_row13_col2, #T_1f8b8_row13_col3, #T_1f8b8_row13_col4, #T_1f8b8_row13_col5, #T_1f8b8_row13_col6, #T_1f8b8_row14_col0, #T_1f8b8_row14_col1, #T_1f8b8_row14_col2, #T_1f8b8_row14_col3, #T_1f8b8_row14_col4, #T_1f8b8_row14_col5, #T_1f8b8_row14_col6, #T_1f8b8_row15_col0, #T_1f8b8_row15_col1, #T_1f8b8_row15_col2, #T_1f8b8_row15_col3, #T_1f8b8_row15_col4, #T_1f8b8_row15_col5, #T_1f8b8_row15_col6, #T_1f8b8_row16_col0, #T_1f8b8_row16_col1, #T_1f8b8_row16_col2, #T_1f8b8_row16_col3, #T_1f8b8_row16_col4, #T_1f8b8_row16_col5, #T_1f8b8_row16_col6, #T_1f8b8_row17_col0, #T_1f8b8_row17_col1, #T_1f8b8_row17_col2, #T_1f8b8_row17_col3, #T_1f8b8_row17_col4, #T_1f8b8_row17_col5, #T_1f8b8_row17_col6 {
#   text-align: left;
# }
# #T_1f8b8_row0_col1, #T_1f8b8_row0_col2, #T_1f8b8_row0_col3, #T_1f8b8_row0_col5, #T_1f8b8_row0_col6, #T_1f8b8_row3_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_1f8b8_row0_col7, #T_1f8b8_row2_col7, #T_1f8b8_row3_col7, #T_1f8b8_row4_col7, #T_1f8b8_row5_col7, #T_1f8b8_row6_col7, #T_1f8b8_row8_col7, #T_1f8b8_row9_col7, #T_1f8b8_row11_col7, #T_1f8b8_row13_col7, #T_1f8b8_row14_col7, #T_1f8b8_row16_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_1f8b8_row1_col7, #T_1f8b8_row7_col7, #T_1f8b8_row10_col7, #T_1f8b8_row12_col7, #T_1f8b8_row15_col7, #T_1f8b8_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_1f8b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f8b8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_1f8b8_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_1f8b8_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_1f8b8_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_1f8b8_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_1f8b8_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_1f8b8_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_1f8b8_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f8b8_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_1f8b8_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_1f8b8_row0_col1" class="data row0 col1" >32.2048</td>
#       <td id="T_1f8b8_row0_col2" class="data row0 col2" >2297.6731</td>
#       <td id="T_1f8b8_row0_col3" class="data row0 col3" >45.5717</td>
#       <td id="T_1f8b8_row0_col4" class="data row0 col4" >-0.5879</td>
#       <td id="T_1f8b8_row0_col5" class="data row0 col5" >0.0554</td>
#       <td id="T_1f8b8_row0_col6" class="data row0 col6" >0.0393</td>
#       <td id="T_1f8b8_row0_col7" class="data row0 col7" >0.0583</td>
#     </tr>
#     <tr>
#       <th id="T_1f8b8_level0_row1" class="row_heading level0 row1" >omp</th>
#       <td id="T_1f8b8_row1_col0" class="data row1 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_1f8b8_row1_col1" class="data row1 col1" >36.4665</td>
#       <td id="T_1f8b8_row1_col2" class="data row1 col2" >2539.1248</td>
#       <td id="T_1f8b8_row1_col3" class="data row1 col3" >46.7146</td>
#       <td id="T_1f8b8_row1_col4" class="data row1 col4" >-0.5131</td>
#       <td id="T_1f8b8_row1_col5" class="data row1 col5" >0.0569</td>
#       <td id="T_1f8b8_row1_col6" class="data row1 col6" >0.0455</td>
#       <td id="T_1f8b8_row1_col7" class="data row1 col7" >0.0050</td>
#     </tr>
#     <tr>
#       <th id="T_1f8b8_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_1f8b8_row2_col0" class="data row2 col0" >Random Forest Regressor</td>
#       <td id="T_1f8b8_row2_col1" class="data row2 col1" >36.9053</td>
#       <td id="T_1f8b8_row2_col2" class="data row2 col2" >2479.3913</td>
#       <td id="T_1f8b8_row2_col3" class="data row2 col3" >47.6877</td>
#       <td id="T_1f8b8_row2_col4" class="data row2 col4" >-0.7996</td>
#       <td id="T_1f8b8_row2_col5" class="data row2 col5" >0.0583</td>
#       <td id="T_1f8b8_row2_col6" class="data row2 col6" >0.0460</td>
#       <td id="T_1f8b8_row2_col7" class="data row2 col7" >0.0183</td>
#     </tr>
#     <tr>
#       <th id="T_1f8b8_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_1f8b8_row3_col0" class="data row3 col0" >Linear Regression</td>
#       <td id="T_1f8b8_row3_col1" class="data row3 col1" >36.9575</td>
#       <td id="T_1f8b8_row3_col2" class="data row3 col2" >2669.0707</td>
#       <td id="T_1f8b8_row3_col3" class="data row3 col3" >47.1474</td>
#       <td id="T_1f8b8_row3_col4" class="data row3 col4" >-0.4471</td>
#       <td id="T_1f8b8_row3_col5" class="data row3 col5" >0.0574</td>
#       <td id="T_1f8b8_row3_col6" class="data row3 col6" >0.0461</td>
#       <td id="T_1f8b8_row3_col7" class="data row3 col7" >0.0183</td>
#     </tr>
#     <tr>
#       <th id="T_1f8b8_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_1f8b8_row4_col0" class="data row4 col0" >Ridge Regression</td>
#       <td id="T_1f8b8_row4_col1" class="data row4 col1" >37.0559</td>
#       <td id="T_1f8b8_row4_col2" class="data row4 col2" >2656.4237</td>
#       <td id="T_1f8b8_row4_col3" class="data row4 col3" >47.2130</td>
#       <td id="T_1f8b8_row4_col4" class="data row4 col4" >-0.4635</td>
#       <td id="T_1f8b8_row4_col5" class="data row4 col5" >0.0575</td>
#       <td id="T_1f8b8_row4_col6" class="data row4 col6" >0.0462</td>
#       <td id="T_1f8b8_row4_col7" class="data row4 col7" >0.0067</td>
#     </tr>
#     <tr>
#       <th id="T_1f8b8_level0_row5" class="row_heading level0 row5" >lar</th>
#       <td id="T_1f8b8_row5_col0" class="data row5 col0" >Least Angle Regression</td>
#       <td id="T_1f8b8_row5_col1" class="data row5 col1" >37.4024</td>
#       <td id="T_1f8b8_row5_col2" class="data row5 col2" >2689.7239</td>
#       <td id="T_1f8b8_row5_col3" class="data row5 col3" >47.3562</td>
#       <td id="T_1f8b8_row5_col4" class="data row5 col4" >-0.4705</td>
#       <td id="T_1f8b8_row5_col5" class="data row5 col5" >0.0577</td>
#       <td id="T_1f8b8_row5_col6" class="data row5 col6" >0.0466</td>
#       <td id="T_1f8b8_row5_col7" class="data row5 col7" >0.0067</td>
#     </tr>
#     <tr

# %% [markdown]
# Light Gradient Boosting Machine (LightGBM) outperformed all other models in almost every category. This could be due to overfitting so let's test it on the test set.

# %%
prediction_holdout = predict_model(comparison[0]);
# Out:
# <style type="text/css">
# </style>
# <table id="T_6cf67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6cf67_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6cf67_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6cf67_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6cf67_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6cf67_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6cf67_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6cf67_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6cf67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6cf67_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6cf67_row0_col1" class="data row0 col1" >38.1687</td>
#       <td id="T_6cf67_row0_col2" class="data row0 col2" >2370.2136</td>
#       <td id="T_6cf67_row0_col3" class="data row0 col3" >48.6848</td>
#       <td id="T_6cf67_row0_col4" class="data row0 col4" >-0.1064</td>
#       <td id="T_6cf67_row0_col5" class="data row0 col5" >0.0580</td>
#       <td id="T_6cf67_row0_col6" class="data row0 col6" >0.0447</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It performed slightly worse on the test data. Let's test next 3 models and see which performs well on the test data.

# %%
# Initialize a dictionary to store the MAE scores
mae_scores = {}

# Iterate through the top 4 models and test them on the test data
for model in comparison:
    # Predict on the test data
    predictions = predict_model(model, data=test)
    
    # Calculate the MAE score
    mae = np.mean(np.abs(predictions['velocity'] - predictions['prediction_label']))
    
    # Store the MAE score in the dictionary
    mae_scores[model] = mae

# Determine the model with the best MAE score
best_model = min(mae_scores, key=mae_scores.get)
best_mae_score = mae_scores[best_model]

print(f"The best model is {best_model} with a MAE score of {best_mae_score:.4f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_f2994">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f2994_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f2994_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_f2994_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_f2994_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_f2994_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_f2994_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_f2994_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2994_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f2994_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f2994_row0_col1" class="data row0 col1" >38.1687</td>
#       <td id="T_f2994_row0_col2" class="data row0 col2" >2370.2136</td>
#       <td id="T_f2994_row0_col3" class="data row0 col3" >48.6848</td>
#       <td id="T_f2994_row0_col4" class="data row0 col4" >-0.1064</td>
#       <td id="T_f2994_row0_col5" class="data row0 col5" >0.0580</td>
#       <td id="T_f2994_row0_col6" class="data row0 col6" >0.0447</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_0bbac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bbac_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_0bbac_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_0bbac_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_0bbac_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_0bbac_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_0bbac_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_0bbac_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bbac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0bbac_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_0bbac_row0_col1" class="data row0 col1" >35.5600</td>
#       <td id="T_0bbac_row0_col2" class="data row0 col2" >2468.5898</td>
#       <td id="T_0bbac_row0_col3" class="data row0 col3" >49.6849</td>
#       <td id="T_0bbac_row0_col4" class="data row0 col4" >-0.1523</td>
#       <td id="T_0bbac_row0_col5" class="data row0 col5" >0.0596</td>
#       <td id="T_0bbac_row0_col6" class="data row0 col6" >0.0430</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_b8962">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8962_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_b8962_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_b8962_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_b8962_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_b8962_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_b8962_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_b8962_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8962_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8962_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_b8962_row0_col1" class="data row0 col1" >32.8528</td>
#       <td id="T_b8962_row0_col2" class="data row0 col2" >2028.5126</td>
#       <td id="T_b8962_row0_col3" class="data row0 col3" >45.0390</td>
#       <td id="T_b8962_row0_col4" class="data row0 col4" >0.0531</td>
#       <td id="T_b8962_row0_col5" class="data row0 col5" >0.0538</td>
#       <td id="T_b8962_row0_col6" class="data row0 col6" >0.0389</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_fd7f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd7f6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_fd7f6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_fd7f6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_fd7f6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_fd7f6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_fd7f6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_fd7f6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd7f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd7f6_row0_col0" class="data row0 col0" >Linear Regression</td>
#       <td id="T_fd7f6_row0_col1" class="data row0 col1" >47.9550</td>
#       <td id="T_fd7f6_row0_col2" class="data row0 col2" >4259.5550</td>
#       <td id="T_fd7f6_row0_col3" class="data row0 col3" >65.2653</td>
#       <td id="T_fd7f6_row0_col4" class="data row0 col4" >-0.9883</td>
#       <td id="T_fd7f6_row0_col5" class="data row0 col5" >0.0771</td>
#       <td id="T_fd7f6_row0_col6" class="data row0 col6" >0.0581</td>
#     </tr>
#   </tbody>
# </table>
# The best model is RandomForestRegressor(n_jobs=-1, random_state=123) with a MAE score of 32.8528

# %% [markdown]
# Random Forest performed the best on the test data. We will use this moving forward.

# %% [markdown]
# ### 5. Tune the model
#
# Here we use hyperparameter tuning to optimize our chosen model. We'll optimize it under mean absolute error (MAE).

# %%
dt = create_model('rf', fold=6)

tune_model(dt, optimize='MAE')
# Out:
# <style type="text/css">
# #T_9548c_row6_col0, #T_9548c_row6_col1, #T_9548c_row6_col2, #T_9548c_row6_col3, #T_9548c_row6_col4, #T_9548c_row6_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_9548c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9548c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_9548c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_9548c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_9548c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_9548c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_9548c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9548c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9548c_row0_col0" class="data row0 col0" >46.5757</td>
#       <td id="T_9548c_row0_col1" class="data row0 col1" >2955.4998</td>
#       <td id="T_9548c_row0_col2" class="data row0 col2" >54.3645</td>
#       <td id="T_9548c_row0_col3" class="data row0 col3" >-0.5671</td>
#       <td id="T_9548c_row0_col4" class="data row0 col4" >0.0668</td>
#       <td id="T_9548c_row0_col5" class="data row0 col5" >0.0592</td>
#     </tr>
#     <tr>
#       <th id="T_9548c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9548c_row1_col0" class="data row1 col0" >49.6955</td>
#       <td id="T_9548c_row1_col1" class="data row1 col1" >3688.1763</td>
#       <td id="T_9548c_row1_col2" class="data row1 col2" >60.7304</td>
#       <td id="T_9548c_row1_col3" class="data row1 col3" >-0.3372</td>
#       <td id="T_9548c_row1_col4" class="data row1 col4" >0.0742</td>
#       <td id="T_9548c_row1_col5" class="data row1 col5" >0.0622</td>
#     </tr>
#     <tr>
#       <th id="T_9548c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9548c_row2_col0" class="data row2 col0" >28.5701</td>
#       <td id="T_9548c_row2_col1" class="data row2 col1" >1216.3119</td>
#       <td id="T_9548c_row2_col2" class="data row2 col2" >34.8757</td>
#       <td id="T_9548c_row2_col3" class="data row2 col3" >-3.0317</td>
#       <td id="T_9548c_row2_col4" class="data row2 col4" >0.0415</td>
#       <td id="T_9548c_row2_col5" class="data row2 col5" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_9548c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9548c_row3_col0" class="data row3 col0" >40.1318</td>
#       <td id="T_9548c_row3_col1" class="data row3 col1" >3876.4787</td>
#       <td id="T_9548c_row3_col2" class="data row3 col2" >62.2614</td>
#       <td id="T_9548c_row3_col3" class="data row3 col3" >-0.4281</td>
#       <td id="T_9548c_row3_col4" class="data row3 col4" >0.0803</td>
#       <td id="T_9548c_row3_col5" class="data row3 col5" >0.0533</td>
#     </tr>
#     <tr>
#       <th id="T_9548c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9548c_row4_col0" class="data row4 col0" >37.5735</td>
#       <td id="T_9548c_row4_col1" class="data row4 col1" >2627.5345</td>
#       <td id="T_9548c_row4_col2" class="data row4 col2" >51.2595</td>
#       <td id="T_9548c_row4_col3" class="data row4 col3" >0.0436</td>
#       <td id="T_9548c_row4_col4" class="data row4 col4" >0.0599</td>
#       <td id="T_9548c_row4_col5" class="data row4 col5" >0.0444</td>
#     </tr>
#     <tr>
#       <th id="T_9548c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9548c_row5_col0" class="data row5 col0" >18.8849</td>
#       <td id="T_9548c_row5_col1" class="data row5 col1" >512.3467</td>
#       <td id="T_9548c_row5_col2" class="data row5 col2" >22.6351</td>
#       <td id="T_9548c_row5_col3" class="data row5 col3" >-0.4771</td>
#       <td id="T_9548c_row5_col4" class="data row5 col4" >0.0270</td>
#       <td id="T_9548c_row5_col5" class="data row5 col5" >0.0227</td>
#     </tr>
#     <tr>
#       <th id="T_9548c_level0_row6" class="row_heading level0 row6" >Mean</th>
#       <td id="T_9548c_row6_col0" class="data row6 col0" >36.9053</td>
#       <td id="T_9548c_row6_col1" class="data row6 col1" >2479.3913</td>
#       <td id="T_9548c_row6_col2" class="data row6 col2" >47.6877</td>
#       <td id="T_9548c_row6_col3" class="data row6 col3" >-0.7996</td>
#       <td id="T_9548c_row6_col4" class="data row6 col4" >0.0583</td>
#       <td id="T_9548c_row6_col5" class="data row6 col5" >0.0460</td>
#     </tr>
#     <tr>
#       <th id="T_9548c_level0_row7" class="row_heading level0 row7" >Std</th>
#       <td id="T_9548c_row7_col0" class="data row7 col0" >10.5053</td>
#       <td id="T_9548c_row7_col1" class="data row7 col1" >1233.3068</td>
#       <td id="T_9548c_row7_col2" class="data row7 col2" >14.3273</td>
#       <td id="T_9548c_row7_col3" class="data row7 col3" >1.0168</td>
#       <td id="T_9548c_row7_col4" class="data row7 col4" >0.0186</td>
#       <td id="T_9548c_row7_col5" class="data row7 col5" >0.0140</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f4ccf_row6_col0, #T_f4ccf_row6_col1, #T_f4ccf_row6_col2, #T_f4ccf_row6_col3, #T_f4ccf_row6_col4, #T_f4ccf_row6_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f4ccf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4ccf_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f4ccf_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f4ccf_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f4ccf_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f4ccf_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f4ccf_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4ccf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4ccf_row0_col0" class="data row0 col0" >32.2257</td>
#       <td id="T_f4ccf_row0_col1" class="data row0 col1" >2250.6570</td>
#       <td id="T_f4ccf_row0_col2" class="data row0 col2" >47.4411</td>
#       <td id="T_f4ccf_row0_col3" class="data row0 col3" >-0.1934</td>
#       <td id="T_f4ccf_row0_col4" class="data row0 col4" >0.0570</td>
#       <td id="T_f4ccf_row0_col5" class="data row0 col5" >0.0388</td>
#     </tr>
#     <tr>
#       <th id="T_f4ccf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f4ccf_row1_col0" class="data row1 col0" >54.2872</td>
#       <td id="T_f4ccf_row1_col1" class="data row1 col1" >4542.5424</td>
#       <td id="T_f4ccf_row1_col2" class="data row1 col2" >67.3984</td>
#       <td id="T_f4ccf_row1_col3" class="data row1 col3" >-0.6470</td>
#       <td id="T_f4ccf_row1_col4" class="data row1 col4" >0.0811</td>
#       <td id="T_f4ccf_row1_col5" class="data row1 col5" >0.0639</td>
#     </tr>
#     <tr>
#       <th id="T_f4ccf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f4ccf_row2_col0" class="data row2 col0" >46.0154</td>
#       <td id="T_f4ccf_row2_col1" class="data row2 col1" >2358.7261</td>
#       <td id="T_f4ccf_row2_col2" class="data row2 col2" >48.5667</td>
#       <td id="T_f4ccf_row2_col3" class="data row2 col3" >-6.8185</td>
#       <td id="T_f4ccf_row2_col4" class="data row2 col4" >0.0590</td>
#       <td id="T_f4ccf_row2_col5" class="data row2 col5" >0.0544</td>
#     </tr>
#     <tr>
#       <th id="T_f4ccf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f4ccf_row3_col0" class="data row3 col0" >35.6285</td>
#       <td id="T_f4ccf_row3_col1" class="data row3 col1" >2746.2370</td>
#       <td id="T_f4ccf_row3_col2" class="data row3 col2" >52.4046</td>
#       <td id="T_f4ccf_row3_col3" class="data row3 col3" >-0.0117</td>
#       <td id="T_f4ccf_row3_col4" class="data row3 col4" >0.0678</td>
#       <td id="T_f4ccf_row3_col5" class="data row3 col5" >0.0458</td>
#     </tr>
#     <tr>
#       <th id="T_f4ccf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f4ccf_row4_col0" class="data row4 col0" >35.5792</td>
#       <td id="T_f4ccf_row4_col1" class="data row4 col1" >2870.6988</td>
#       <td id="T_f4ccf_row4_col2" class="data row4 col2" >53.5789</td>
#       <td id="T_f4ccf_row4_col3" class="data row4 col3" >-0.0450</td>
#       <td id="T_f4ccf_row4_col4" class="data row4 col4" >0.0619</td>
#       <td id="T_f4ccf_row4_col5" class="data row4 col5" >0.0407</td>
#     </tr>
#     <tr>
#       <th id="T_f4ccf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f4ccf_row5_col0" class="data row5 col0" >13.8449</td>
#       <td id="T_f4ccf_row5_col1" class="data row5 col1" >328.1206</td>
#       <td id="T_f4ccf_row5_col2" class="data row5 col2" >18.1141</td>
#       <td id="T_f4ccf_row5_col3" class="data row5 col3" >0.0540</td>
#       <td id="T_f4ccf_row5_col4" class="data row5 col4" >0.0218</td>
#       <td id="T_f4ccf_row5_col5" class="data row5 col5" >0.0166</td>
#     </tr>
#     <tr>
#       <th id="T_f4ccf_level0_row6" class="row_heading level0 row6" >Mean</th>
#       <td id="T_f4ccf_row6_col0" class="data row6 col0" >36.2635</td>
#       <td id="T_f4ccf_row6_col1" class="data row6 col1" >2516.1636</td>
#       <td id="T_f4ccf_row6_col2" class="data row6 col2" >47.9173</td>
#       <td id="T_f4ccf_row6_col3" class="data row6 col3" >-1.2769</td>
#       <td id="T_f4ccf_row6_col4" class="data row6 col4" >0.0581</td>
#       <td id="T_f4ccf_row6_col5" class="data row6 col5" >0.0434</td>
#     </tr>
#     <tr>
#       <th id="T_f4ccf_level0_row7" class="row_heading level0 row7" >Std</th>
#       <td id="T_f4ccf_row7_col0" class="data row7 col0" >12.5148</td>
#       <td id="T_f4ccf_row7_col1" class="data row7 col1" >1236.0996</td>
#       <td id="T_f4ccf_row7_col2" class="data row7 col2" >14.8357</td>
#       <td id="T_f4ccf_row7_col3" class="data row7 col3" >2.4890</td>
#       <td id="T_f4ccf_row7_col4" class="data row7 col4" >0.0180</td>
#       <td id="T_f4ccf_row7_col5" class="data row7 col5" >0.0147</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 6 folds for each of 10 candidates, totalling 60 fits
# RandomForestRegressor(bootstrap=False, max_depth=11, max_features='sqrt',
#                       min_impurity_decrease=0.0002, min_samples_leaf=5,
#                       min_samples_split=7, n_estimators=200, n_jobs=-1,
#                       random_state=123)

# %% [markdown]
# The tuned random forest performed very slightly better than the original. We'll use these parameters moving forward.
